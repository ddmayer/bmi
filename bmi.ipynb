# %%
import pandas as pd

bmi_boys_perc_WHO2007_exp = pd.read_csv('bmi_boys_perc_WHO2007_exp.csv')
bmi_girls_perc_WHO2007_exp = pd.read_csv('bmi_girls_perc_WHO2007_exp.csv')

bmi_boys_perc_WHO2007_exp
# Out:
#      Unnamed: 0  Month       L        M        S     P01      P1      P3  \
# 0             0     61 -0.7387  15.2641  0.08390  12.041  12.720  13.148
# 1             1     62 -0.7621  15.2616  0.08414  12.039  12.716  13.144
# 2             2     63 -0.7856  15.2604  0.08439  12.037  12.714  13.140
# 3             3     64 -0.8089  15.2605  0.08464  12.037  12.712  13.138
# 4             4     65 -0.8322  15.2619  0.08490  12.038  12.711  13.137
# 5             5     66 -0.8554  15.2645  0.08516  12.039  12.712  13.137
# 6             6     67 -0.8785  15.2684  0.08543  12.042  12.713  13.138
# 7             7     68 -0.9015  15.2737  0.08570  12.045  12.715  13.140
# 8             8     69 -0.9243  15.2801  0.08597  12.049  12.718  13.143
# 9             9     70 -0.9471  15.2877  0.08625  12.054  12.722  13.146
# 10           10     71 -0.9697  15.2965  0.08653  12.060  12.727  13.151
# 11           11     72 -0.9921  15.3062  0.08682  12.066  12.733  13.157
# ...

# %%
from datetime import datetime
now = datetime.now()
birthday = datetime.strptime('2011/02/10', '%Y/%m/%d')

# %%
age = now - birthday #(日,秒,微秒)
age
# Out:
# datetime.timedelta(2871, 69749, 538283)

# %%
weight = 58
height = 171

# %%
height /= 100
bmi = weight/(height**2)
